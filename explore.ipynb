# %%
import sys
import os
sys.path.insert(0, "compass")

import random
import cProfile
import numpy as np
from parameters import FLAGS
from model import CompassModel

# Set seeds for reproducibility
random.seed(3)
np.random.seed(3)

# %%
import os
import pickle

dir_path = os.getcwd()
file_path = os.path.join(dir_path, "compass/maps/ijburg/agents_ijburg.pickle")
file = open(file_path, "rb")
data = pickle.load(file)
# Out:
# /home/jiqi/.local/share/virtualenvs/school-choice---understanding-segregation-rFYzdyjw/lib/python3.8/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
new_path = os.path.join(dir_path, "compass/maps/ijburg/agents_ijburg_new.pickle")
file_new = open(new_path, "wb")
pickle.dump(obj=data, file=file_new)

# %%
data.keys()
# Out:
# dict_keys(['neighbourhoods', 'schools', 'households', 'neighbourhoods_gpd', 'agents', 'perc_of_actual', 'distances', 'closest_schools', 'furthest_schools'])

# %%
pip list | grep pandas
# Out:
# geopandas            0.10.2
# pandas               1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
sn = data["neighbourhoods_gpd"]
sn
# Out:
#    Buurt_code                                           geometry  \
# 0        M35a  POLYGON ((554838.272 6867253.819, 555099.094 6...
# 1        M35b  POLYGON ((553483.403 6865955.240, 553997.699 6...
# 2        M35c  POLYGON ((554875.007 6865285.888, 555085.290 6...
# 3        M51a  POLYGON ((556378.043 6863592.522, 556549.141 6...
# 4        M35e  POLYGON ((556738.050 6867046.885, 557126.889 6...
# 5        M35f  POLYGON ((555693.874 6864936.469, 556041.079 6...
# 6        M50b  POLYGON ((558782.433 6865083.380, 560912.754 6...
# 7        M50e  POLYGON ((557290.306 6866005.371, 558713.192 6...
# 8        M50c  POLYGON ((558713.192 6866001.543, 560873.904 6...
# 9        M50f  POLYGON ((556738.050 6867046.885, 558204.907 6...
# 10       M51c  POLYGON ((556680.610 6864077.476, 557029.930 6...
# 11       M50a  POLYGON ((558809.818 6864720.482, 560917.986 6...
# 12       M50d  POLYGON ((558130.991 6864888.168, 558782.433 6...
# ...

# %%
sn.dtypes
# Out:
# Buurt_code      object
# geometry      geometry
# object          object
# x               object
# y               object
# shape           object
# size            object
# color           object
# group          float64
# dtype: object

# %%
shape = sn.iloc[0]["geometry"]
type(shape)
# Out:
# shapely.geometry.polygon.Polygon

# %%
data["agents"].describe()
# Out:
#              group
# count  8482.000000
# mean      0.337303
# std       0.472817
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
